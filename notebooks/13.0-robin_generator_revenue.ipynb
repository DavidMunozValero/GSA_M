# %% [markdown]
# # Infraestructure Manager revenue maximization with GSA

# %% [markdown]
# ## 0. Load libraries
#
# ### WARNING!
#
# Install local robin module: `python3 -m pip install -e /Users/david/PycharmProjects/robin`

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from benchmarks.robin_railway import RevenueMaximization
from benchmarks.generator import get_revenue_behaviour_old

schedule = {'1': {'Madrid': [1100, 1100], 'Lleida': [1195, 1195]},
            '2': {'Zaragoza': [1190, 1190], 'Barcelona': [1260, 1260]},
            '3': {'Madrid': [1080, 1080], 'Calatayud': [1130, 1134], 'Lleida': [1210, 1214], 'Barcelona': [1280, 1280]}}

schedule = {'1': {'Madrid': [1244.0, 1244.0], 'Barcelona': [1394.0, 1394.0]},
            '2': {'Zaragoza': [1282.0, 1282.0], 'Barcelona': [1392.0, 1392.0]},
            '3': {'Madrid': [1354.0, 1354.0],
                  'Calatayud': [1409.0, 1410.0],
                  'Zaragoza': [1435.0, 1441.0],
                  'Lleida': [1484.0, 1488.0],
                  'Tarragona': [1515.0, 1519.0],
                  'Barcelona': [1555.0, 1555.0]}
            }

schedule = {'5': {'Zaragoza': [728, 728], 'Barcelona': [838, 838]},
            '25': {'Madrid': [647, 647],
                   'Calatayud': [702, 706],
                   'Zaragoza': [731, 733],
                   'Lleida': [776, 783],
                   'Tarragona': [810, 813],
                   'Barcelona': [849, 849]}
            }
schedule = {'6': {'Madrid': [130.0, 130.0],
                  'Zaragoza': [205.0, 212.0],
                  'Tarragona': [285.0, 289.0],
                  'Barcelona': [322.0, 322.0]},
             '26': {'Zaragoza': [216.0, 216.0],
                   'Barcelona': [326.0, 326.0]},
            }

schedule = {'15': {'Madrid': [412.0, 412.0], 'Barcelona': [562.0, 562.0]},
            '39': {'Zaragoza': [424.0, 424.0], 'Barcelona': [534.0, 534.0]}
            }

schedule = {'1': {'Madrid': [1055, 1055], 'Lleida': [1150, 1150]},
            '2': {'Zaragoza': [1210, 1210], 'Barcelona': [1283, 1283]},
            '3': {'Madrid': [1080, 1080], 'Calatayud': [1130, 1134], 'Lleida': [1210, 1214],
                  'Barcelona': [1280, 1280]}
	       }

line_stations = {'Madrid': (40.406442, -3.690886),
                 'Calatayud': (41.346692, -1.63868),
                 'Zaragoza': (41.658649, -0.911615),
                 'Lleida': (41.620696, 0.632669),
                 'Tarragona': (41.111624, 1.253214),
                 'Barcelona': (41.37922, 2.140624)}

revenue = get_revenue_behaviour_old(schedule)

sm = RevenueMaximization(requested_schedule=schedule,
                         revenue_behaviour=revenue,
                         line=line_stations)

print(sm.conflict_matrix)
# Out:
# [[False False  True]
#  [False False  True]
#  [ True  True False]]

# %%
sm.operational_times
# Out:
# {'1': [95], '2': [73], '3': [50, 4, 76, 4, 66]}

# %%
from benchmarks.utils import TrainSchedulePlotter

schedule_plotter = TrainSchedulePlotter(schedule, line_stations)
schedule_plotter.plot(main_title=f"Railway Marey chart - Requests Example",
                      save_path='../figures/example.pdf')

# %%
security_gap = 10
schedule_plotter.plot(main_title=f"Railway Marey chart - Safety gaps",
                      plot_security_gaps=True,
                      security_gap=security_gap,
                      save_path='../figures/example_security_gaps.pdf')
# Out:
# /Users/david/PycharmProjects/GSA_M/venv/lib/python3.9/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
from src.entities import GSA

gsa_algo = GSA(objective_function=sm.get_fitness_gsa,
               is_feasible=sm.feasible_services_times,
               custom_repair=sm.custom_repair,
               r_dim=len(sm.boundaries.real),
               d_dim=0,
               boundaries=sm.boundaries)

# %%
import cProfile as profile
import time

pr = profile.Profile()
pr.disable()

#gsa_algo.set_seed()

pop_size = 30

start = time.time()
pr.enable()
training_history = gsa_algo.optimize(population_size=pop_size,
                                     iters=50,
                                     chaotic_constant=True,
                                     repair_solution=True,
                                     initial_population=sm.get_initial_population(pop_size),
                                     verbose=True)
pr.disable()
print(f"Elapsed time: {round(time.time() - start, 2)} seconds")

pr.dump_stats('profile.pstat')
# Out:
# GSA is optimizing  "get_fitness_gsa"
# ['At iteration 1 the best fitness is 2091.583613277351']
# ['At iteration 2 the best fitness is 2355.9722079843727']
# ['At iteration 3 the best fitness is 2355.9722079843727']
# ['At iteration 4 the best fitness is 2355.9722079843727']
# ['At iteration 5 the best fitness is 2355.9722079843727']
# ['At iteration 6 the best fitness is 2355.9722079843727']
# ['At iteration 7 the best fitness is 2355.9722079843727']
# ['At iteration 8 the best fitness is 2355.9722079843727']
# ['At iteration 9 the best fitness is 2365.8344928972356']
# ['At iteration 10 the best fitness is 2375.0446777032816']
# ['At iteration 11 the best fitness is 2375.0446777032816']
# ['At iteration 12 the best fitness is 2375.0446777032816']
# ['At iteration 13 the best fitness is 2375.0446777032816']
# ['At iteration 14 the best fitness is 2375.0446777032816']
# ['At iteration 15 the best fitness is 2375.0446777032816']
# ['At iteration 16 the best fitness is 2375.0446777032816']
# ['At iteration 17 the best fitness is 2375.0446777032816']
# ['At iteration 18 the best fitness is 2375.0446777032816']
# ['At iteration 19 the best fitness is 2375.0446777032816']
# ['At iteration 20 the best fitness is 2375.0446777032816']
# ['At iteration 21 the best fitness is 2375.0446777032816']
# ['At iteration 22 the best fitness is 2375.0446777032816']
# ['At iteration 23 the best fitness is 2375.0446777032816']
# ['At iteration 24 the best fitness is 2375.0446777032816']
# ['At iteration 25 the best fitness is 2375.0446777032816']
# ['At iteration 26 the best fitness is 2375.0446777032816']
# ['At iteration 27 the best fitness is 2375.0446777032816']
# ['At iteration 28 the best fitness is 2375.0446777032816']
# ['At iteration 29 the best fitness is 2375.0446777032816']
# ['At iteration 30 the best fitness is 2375.0446777032816']
# ['At iteration 31 the best fitness is 2375.0446777032816']
# ['At iteration 32 the best fitness is 2375.0446777032816']
# ['At iteration 33 the best fitness is 2375.0446777032816']
# ['At iteration 34 the best fitness is 2375.0446777032816']
# ['At iteration 35 the best fitness is 2375.0446777032816']
# ['At iteration 36 the best fitness is 2375.0446777032816']
# ['At iteration 37 the best fitness is 2375.0446777032816']
# ['At iteration 38 the best fitness is 2375.0446777032816']
# ['At iteration 39 the best fitness is 2375.0446777032816']
# ['At iteration 40 the best fitness is 2375.0446777032816']
# ['At iteration 41 the best fitness is 2375.0446777032816']
# ['At iteration 42 the best fitness is 2375.0446777032816']
# ['At iteration 43 the best fitness is 2375.0446777032816']
# ['At iteration 44 the best fitness is 2375.0446777032816']
# ['At iteration 45 the best fitness is 2375.0446777032816']
# ['At iteration 46 the best fitness is 2375.0446777032816']
# ['At iteration 47 the best fitness is 2375.0446777032816']
# ['At iteration 48 the best fitness is 2375.0446777032816']
# ['At iteration 49 the best fitness is 2375.0446777032816']
# ['At iteration 50 the best fitness is 2375.0446777032816']
# <src.entities.Solution object at 0x30cf1f160>
# Elapsed time: 0.52 seconds

# %%
revenue
# Out:
# {'1': {'canon': 830.0,
#   'k': 1.01,
#   'dt_max_penalty': 116.2,
#   'tt_max_penalty': 215.8},
#  '2': {'canon': 830.0,
#   'k': 1.02,
#   'dt_max_penalty': 116.2,
#   'tt_max_penalty': 215.8},
#  '3': {'canon': 1660.0,
#   'k': 1.01,
#   'dt_max_penalty': 232.4,
#   'tt_max_penalty': 143.87}}

# %%
sm.best_solution.real, sm.best_solution.discrete
# Out:
# (array([1051, 1219, 1080, 1134, 1214]), array([False,  True,  True]))

# %%
sm.update_schedule(solution=sm.best_solution)

schedule_plotter = TrainSchedulePlotter(sm.updated_schedule, line_stations)
security_gap = 10
schedule_plotter.plot(main_title=f"Railway Marey chart - Safety gaps (Solution)",
                      plot_security_gaps=True,
                      security_gap=security_gap,
                      save_path='../figures/example_security_gaps.pdf')

# %%
sm.conflict_matrix
# Out:
# array([[False, False,  True],
#        [False, False, False],
#        [ True, False, False]])

# %%
sm.get_revenue(sm.best_solution)
# Out:
# 987.7

# %%
sm.is_feasible(sm.best_solution, sm.best_solution.discrete)
# Out:
# True

# %%
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 6))

ax.set_title("Fitness", fontweight='bold')

# ax.set_ylim(min(global_train_hist["Fitness"]), max(global_train_hist["Fitness"]))
    
sns.lineplot(ax=ax,
             data=training_history,
             x="Iteration",
             y="Fitness",
             legend=True)

ax.grid(axis='y', color='#A9A9A9', alpha=0.3, zorder=1)

ax.set_xlabel("Iter.")
ax.set_ylabel("Fitness")

plt.show()
# fig.savefig(save_path, format='svg', dpi=300, bbox_inches='tight', transparent=True)

# %%
# !snakeviz profile.pstat
# Out:
# snakeviz web server started on 127.0.0.1:8080; enter Ctrl-C to exit
# http://127.0.0.1:8080/snakeviz/%2FUsers%2Fdavid%2FPycharmProjects%2FGSA_M%2Fnotebooks%2Fprofile.pstat
# ^C
#
# Bye!

# %%
sum([sm.revenue[service]['canon'] for service in sm.revenue])
# Out:
# 643.5

# %%
training_history
# Out:
#     Iteration     Fitness  Accuracy  ExecutionTime Discrete  \
# 0           0  624.376168         0       0.005983       []
# 1           1  624.376168         0       0.016689       []
# 2           2  625.914299         0       0.027098       []
# 3           3  625.914299         0       0.035553       []
# 4           4  637.798558         0       0.043507       []
# ..        ...         ...       ...            ...      ...
# 95         95  643.500000         0       0.635287       []
# 96         96  643.500000         0       0.639542       []
# 97         97  643.500000         0       0.643556       []
# 98         98  643.500000         0       0.647989       []
# 99         99  643.500000         0       0.652447       []
#
#                                       Real
# 0             [1250, 819, 1222, 1174, 958]
# 1             [1250, 819, 1222, 1174, 958]
# 2   [1249.0, 818.0, 1229.0, 1178.0, 960.0]
# 3   [1249.0, 818.0, 1229.0, 1178.0, 960.0]
# 4   [1247.0, 820.0, 1224.0, 1176.0, 962.0]
# ..                                     ...
# 95  [1248.0, 821.0, 1224.0, 1177.0, 960.0]
# 96  [1248.0, 821.0, 1224.0, 1177.0, 960.0]
# 97  [1248.0, 821.0, 1224.0, 1177.0, 960.0]
# 98  [1248.0, 821.0, 1224.0, 1177.0, 960.0]
# 99  [1248.0, 821.0, 1224.0, 1177.0, 960.0]
#
# [100 rows x 6 columns]

# %%
from robin.scraping.entities import SupplySaver

supply_save_path = '../configs/gsa_results/'

if not Path(supply_save_path).exists():
    Path(supply_save_path).mkdir(parents=True)
    
SupplySaver(services).to_yaml(filename='supply.yml', save_path='../configs/gsa_results/')

# %%
from robin.kernel.entities import Kernel

path_config_supply = '../configs/gsa_results/supply.yml'
path_config_demand = '../configs/demand/demand.yml'
path_output_csv = '../data/output/robin/output.csv'

if not Path(path_output_csv).parent.exists():
    Path(path_output_csv).parent.mkdir(parents=True)
    
seed = 0

kernel = Kernel(path_config_supply, path_config_demand, seed)
services = kernel.simulate(output_path=path_output_csv, departure_time_hard_restriction=True)

# %%
import pandas as pd

df = pd.read_csv(path_output_csv)
df
# Out:
#         id user_pattern  departure_station  arrival_station arrival_day  \
# 0       42      Tourist              60000             4040  2023-06-25
# 1       56      Tourist              60000             4040  2023-06-25
# 2       65      Tourist              60000             4040  2023-06-25
# 3       87      Tourist              60000             4040  2023-06-25
# 4      112      Tourist              60000             4040  2023-06-25
# ...    ...          ...                ...              ...         ...
# 9205  8869      Student              60000            71801  2023-06-25
# 9206  8962      Student              60000            71801  2023-06-25
# 9207  9051      Student              60000            71801  2023-06-25
# 9208  9177      Student              60000            71801  2023-06-25
# 9209  9191      Student              60000            71801  2023-06-25
#
#       arrival_time  purchase_day service  service_departure_time  \
# 0         9.731107            14     NaN                     NaN
# 1         6.104585            14     NaN                     NaN
# 2        19.097141            14     NaN                     NaN
# 3         7.306265            14     NaN                     NaN
# 4        11.312883            14     NaN                     NaN
# ...            ...           ...     ...                     ...
# 9205     18.642302             0     NaN                     NaN
# 9206     17.055001             0     NaN                     NaN
# 9207     18.623643             0     NaN                     NaN
# 9208     21.304901             0     NaN                     NaN
# 9209     12.302737             0     NaN                     NaN
#
#       service_arrival_time seat  price  utility            best_service  \
# 0                      NaN  NaN    NaN      NaN                     NaN
# 1                      NaN  NaN    NaN      NaN                     NaN
# 2                      NaN  NaN    NaN      NaN                     NaN
# 3                      NaN  NaN    NaN      NaN                     NaN
# 4                      NaN  NaN    NaN      NaN                     NaN
# ...                    ...  ...    ...      ...                     ...
# 9205                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
# 9206                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
# 9207                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
# 9208                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
# 9209                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
#
#      best_seat  best_utility
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          NaN           NaN
# 4          NaN           NaN
# ...        ...           ...
# 9205   Turista     25.461875
# 9206   Turista     25.461875
# 9207   Turista     25.461875
# 9208   Turista     25.461875
# 9209   Turista     25.461875
#
# [9210 rows x 16 columns]

# %%
from robin.supply.entities import Supply

supply = Supply.from_yaml(path_config_supply)

services_tsp = {service.id: service.tsp.name for service in supply.services}

# %%
import numpy as np

df['tsp'] = df['service'].apply(lambda service_id: services_tsp.get(service_id, np.NaN))
df
# Out:
#         id user_pattern  departure_station  arrival_station arrival_day  \
# 0       42      Tourist              60000             4040  2023-06-25
# 1       56      Tourist              60000             4040  2023-06-25
# 2       65      Tourist              60000             4040  2023-06-25
# 3       87      Tourist              60000             4040  2023-06-25
# 4      112      Tourist              60000             4040  2023-06-25
# ...    ...          ...                ...              ...         ...
# 9205  8869      Student              60000            71801  2023-06-25
# 9206  8962      Student              60000            71801  2023-06-25
# 9207  9051      Student              60000            71801  2023-06-25
# 9208  9177      Student              60000            71801  2023-06-25
# 9209  9191      Student              60000            71801  2023-06-25
#
#       arrival_time  purchase_day service  service_departure_time  \
# 0         9.731107            14     NaN                     NaN
# 1         6.104585            14     NaN                     NaN
# 2        19.097141            14     NaN                     NaN
# 3         7.306265            14     NaN                     NaN
# 4        11.312883            14     NaN                     NaN
# ...            ...           ...     ...                     ...
# 9205     18.642302             0     NaN                     NaN
# 9206     17.055001             0     NaN                     NaN
# 9207     18.623643             0     NaN                     NaN
# 9208     21.304901             0     NaN                     NaN
# 9209     12.302737             0     NaN                     NaN
#
#       service_arrival_time seat  price  utility            best_service  \
# 0                      NaN  NaN    NaN      NaN                     NaN
# 1                      NaN  NaN    NaN      NaN                     NaN
# 2                      NaN  NaN    NaN      NaN                     NaN
# 3                      NaN  NaN    NaN      NaN                     NaN
# 4                      NaN  NaN    NaN      NaN                     NaN
# ...                    ...  ...    ...      ...                     ...
# 9205                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
# 9206                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
# 9207                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
# 9208                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
# 9209                   NaN  NaN    NaN      NaN  03612_2024-06-25-16.00
#
#      best_seat  best_utility  tsp
# 0          NaN           NaN  NaN
# 1          NaN           NaN  NaN
# 2          NaN           NaN  NaN
# 3          NaN           NaN  NaN
# 4          NaN           NaN  NaN
# ...        ...           ...  ...
# 9205   Turista     25.461875  NaN
# 9206   Turista     25.461875  NaN
# 9207   Turista     25.461875  NaN
# 9208   Turista     25.461875  NaN
# 9209   Turista     25.461875  NaN
#
# [9210 rows x 17 columns]

# %%
tsp_revenue = df.groupby('tsp').agg({'price': 'sum'}).to_dict()['price']
tsp_revenue
# Out:
# {'IRYO': 36001.5, 'Renfe AVE': 34742.0}
