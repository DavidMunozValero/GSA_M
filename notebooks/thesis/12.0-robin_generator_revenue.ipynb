# %% [markdown]
# # Labs

# %% [markdown]
# ## 0. Load libraries
#
# ### WARNING!
#
# Install local robin module: `python3 -m pip install -e /Users/david/PycharmProjects/robin`

# %%
# %load_ext autoreload
# %autoreload 2

import shutil

from benchmarks.rm_dynamics import RailwayMarketDynamics

from pathlib import Path

# %%
# Config files
supply_config_path = Path("../configs/generator/supply_config.yml")
demand_config_path = Path("../configs/demand/demand.yml")
generator_config_path = Path("../configs/generator/generator_config.yml")

# Save paths
generator_save_path = Path(f'../data/supply_dummy.yml')
supply_save_path = '../configs/gsa_results/'
robin_save_path = '../data/output/robin/'
figures = '../figures/'

# Clean save paths directories
if Path(supply_save_path).exists():
    shutil.rmtree(supply_save_path)
    
Path(supply_save_path).mkdir(parents=True)

if Path(robin_save_path).exists():
    shutil.rmtree(robin_save_path)
    
Path(robin_save_path).mkdir(parents=True)

if Path(figures).exists():
    shutil.rmtree(figures)

Path(figures).mkdir(parents=True)

# %%
rmd = RailwayMarketDynamics(supply_config_path=supply_config_path,
                            demand_config_path=demand_config_path,
                            generator_config_path=generator_config_path,
                            generator_save_path=generator_save_path,
                            seed = 21)
# Out:
# Number of service requests generated: 20

# %%
services = rmd.run(gsa_supply_save_path=supply_save_path,
                    robin_save_path=Path(f'{robin_save_path}output.csv'),
                    gsa_population=20,
                    gsa_iters=50,
                    gsa_runs=1,
                    gsa_chaotic=True,
                    gsa_verbosity=False)
# Out:
#        Number of Services
# AVLO                    4
# IRYO                    8
# AVE                     5
# OUIGO                   3
# Total                  20
#   0%|          | 0/1 [00:00<?, ?it/s]
#    Run      Revenue  Execution Time (s.)  Scheduled Trains  Delta DT (min.)  \
# 0    1  3045.920517             4.838945                13              8.0
#
#    Delta TT (min.)    IRYO    AVLO     AVE    OUIGO
# 0             96.0  50.0 %  62.5 %  60.0 %  100.0 %
# Global GSA status:
# 	Total execution time: 4.8389 s.
# 	Execution Time (by run) - Mean: 4.8389 s. - Std: nan s.
# 	Revenue - Mean: 3045.9205 - Std: nan
# 	Scheduled Trains - Mean: 13.0 - Std: nan
# 	Median solution: Run 1
# 	Max Revenue: 4559.5 - WARNING!: Scheduling all services could not be feasible
# {'1_2024-06-25-14.32': {'60000': [870.0, 870.0], '04040': [945.0, 949.0], '71500': [1022.0, 1026.0], '71801': [1059.0, 1059.0]}, '3_2024-06-25-13.47': {'60000': [826.0, 826.0], '70600': [881.0, 883.0], '04040': [908.0, 909.0], '78400': [952.0, 954.0], '71500': [981.0, 988.0], '71801': [1024.0, 1024.0]}, '4_2024-06-25-22.34': {'60000': [1354.0, 1354.0], '71801': [1504.0, 1504.0]}, '5_2024-06-25-12.09': {'60000': [729.0, 729.0], '04040': [804.0, 809.0], '71500': [882.0, 887.0], '71801': [920.0, 920.0]}, '6_2024-06-25-2.10': {'60000': [130.0, 130.0], '04040': [205.0, 207.0], '71500': [280.0, 282.0], '71801': [315.0, 315.0]}, '8_2024-06-25-8.51': {'60000': [531.0, 531.0], '70600': [586.0, 587.0], '04040': [612.0, 616.0], '78400': [659.0, 665.0], '71500': [692.0, 695.0], '71801': [731.0, 731.0]}, '9_2024-06-25-15.24': {'60000': [924.0, 924.0], '70600': [979.0, 982.0], '04040': [1007.0, 1014.0], '78400': [1057.0, 1060.0], '71500': [1087.0, 1090.0], '71801': [1126.0, 1126.0]}, '11_2024-06-25-3.05': {'60000': [186.0, 186.0], '71801': [336.0, 336.0]}, '12_2024-06-25-6.38': {'60000': [399.0, 399.0], '71801': [549.0, 549.0]}, '14_2024-06-25-19.21': {'60000': [1160.0, 1160.0], '70600': [1215.0, 1219.0], '04040': [1244.0, 1247.0], '78400': [1290.0, 1295.0], '71500': [1322.0, 1324.0], '71801': [1360.0, 1360.0]}, '15_2024-06-25-6.52': {'60000': [411.0, 411.0], '71801': [561.0, 561.0]}, '16_2024-06-25-4.33': {'60000': [273.0, 273.0], '71801': [423.0, 423.0]}, '18_2024-06-25-17.59': {'60000': [1078.0, 1078.0], '70600': [1133.0, 1136.0], '04040': [1161.0, 1163.0], '78400': [1206.0, 1208.0], '71500': [1235.0, 1243.0], '71801': [1279.0, 1279.0]}}
# Data from demand plot:
# 	Status: User found  any service that met his needs but couldn't purchase. - Passengers: 4012
# 	Status: User bought a service which was not the one with the best utility. - Passengers: 2643
# 	Status: User bought the ticket with best utility. - Passengers: 1123
# 	Status: User didn't find any ticket that met his needs. - Passengers: 0
#
# Data from pie chart:
# 	Total tickets sold:  3766
# 	Percentage of tickets sold by seat type:
# 		Seat: Premium - Passengers: 499 - Percentage: 13.25 %
# 		Seat: Turista - Passengers: 2720 - Percentage: 72.23 %
# 		Seat: TuristaPlus - Passengers: 547 - Percentage: 14.52 %
#
# Data from plot tickets sold by purchase day:
# 	Total tickets sold:  3766
# 	Tickets sold by purchase date and seat type:
# 		Date: 2023-06-11
# 			Seat: Premium - Number of tickets sold: 56
# 			Seat: Turista - Number of tickets sold: 63
# 		Date: 2023-06-12
# 			Seat: Premium - Number of tickets sold: 5
# 			Seat: Turista - Number of tickets sold: 57
# 		Date: 2023-06-13
# 			Seat: Premium - Number of tickets sold: 3
# 			Seat: Turista - Number of tickets sold: 67
# 		Date: 2023-06-14
# 			Seat: Turista - Number of tickets sold: 68
# 		Date: 2023-06-15
# 			Seat: Turista - Number of tickets sold: 67
# 		Date: 2023-06-16
# 			Seat: Turista - Number of tickets sold: 55
# 		Date: 2023-06-17
# 			Seat: Turista - Number of tickets sold: 53
# 		Date: 2023-06-18
# 			Seat: Turista - Number of tickets sold: 63
# 		Date: 2023-06-19
# 			Seat: Premium - Number of tickets sold: 284
# 			Seat: Turista - Number of tickets sold: 163
# 		Date: 2023-06-20
# 			Seat: Premium - Number of tickets sold: 99
# 			Seat: Turista - Number of tickets sold: 272
# 		Date: 2023-06-21
# 			Seat: Premium - Number of tickets sold: 2
# 			Seat: Turista - Number of tickets sold: 394
# 		Date: 2023-06-22
# 			Seat: Premium - Number of tickets sold: 50
# 			Seat: Turista - Number of tickets sold: 531
# 			Seat: TuristaPlus - Number of tickets sold: 183
# 		Date: 2023-06-23
# 			Seat: Turista - Number of tickets sold: 506
# 			Seat: TuristaPlus - Number of tickets sold: 183
# 		Date: 2023-06-24
# 			Seat: Turista - Number of tickets sold: 196
# 			Seat: TuristaPlus - Number of tickets sold: 139
# 		Date: 2023-06-25
# 			Seat: Turista - Number of tickets sold: 165
# 			Seat: TuristaPlus - Number of tickets sold: 42
#
# Data from plot tickets sold by purchase date, user and seat type:
# 	Total tickets sold:  3766
# 	Tickets sold by purchase date, user and seat type:
# 		Date: 2023-06-11
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 63
# 				Seat: Premium - Tickets sold: 56
# 		Date: 2023-06-12
# 			User: Tourist
# 				Seat: Premium - Tickets sold: 5
# 				Seat: Turista - Tickets sold: 57
# 		Date: 2023-06-13
# 			User: Tourist
# 				Seat: Premium - Tickets sold: 3
# 				Seat: Turista - Tickets sold: 67
# 		Date: 2023-06-14
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 68
# 		Date: 2023-06-15
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 67
# 		Date: 2023-06-16
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 55
# 		Date: 2023-06-17
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 53
# 		Date: 2023-06-18
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 63
# 		Date: 2023-06-19
# 			User: Business
# 				Seat: Premium - Tickets sold: 284
# 				Seat: Turista - Tickets sold: 101
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 62
# 		Date: 2023-06-20
# 			User: Business
# 				Seat: Premium - Tickets sold: 99
# 				Seat: Turista - Tickets sold: 219
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 53
# 		Date: 2023-06-21
# 			User: Business
# 				Seat: Turista - Tickets sold: 326
# 				Seat: Premium - Tickets sold: 2
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 68
# 		Date: 2023-06-22
# 			User: Student
# 				Seat: Turista - Tickets sold: 135
# 				Seat: TuristaPlus - Tickets sold: 183
# 				Seat: Premium - Tickets sold: 50
# 			User: Business
# 				Seat: Turista - Tickets sold: 333
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 63
# 		Date: 2023-06-23
# 			User: Student
# 				Seat: TuristaPlus - Tickets sold: 183
# 				Seat: Turista - Tickets sold: 131
# 			User: Business
# 				Seat: Turista - Tickets sold: 313
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 62
# 		Date: 2023-06-24
# 			User: Student
# 				Seat: TuristaPlus - Tickets sold: 139
# 				Seat: Turista - Tickets sold: 140
# 			User: Tourist
# 				Seat: Turista - Tickets sold: 56
# 		Date: 2023-06-25
# 			User: Student
# 				Seat: Turista - Tickets sold: 165
# 				Seat: TuristaPlus - Tickets sold: 42
#
# Data from plot tickets sold by pair of stations
# 	Total tickets sold:  3766
# 	Tickets sold by pair of stations:
# 		Pair: Madrid-Puerta de Atocha - Barcelona-Sants - Tickets: 2086
# 		Pair: Madrid-Puerta de Atocha - Zaragoza-Delicias - Tickets: 1001
# 		Pair: Zaragoza-Delicias - Barcelona-Sants - Tickets: 679
# {'Tourist': {'Turista': 857, 'Premium': 64}, 'Business': {'Premium': 385, 'Turista': 1292}, 'Student': {'Turista': 571, 'TuristaPlus': 547, 'Premium': 50}}

# %%
# !snakeviz profile.pstat
# Out:
# snakeviz web server started on 127.0.0.1:8080; enter Ctrl-C to exit
# http://127.0.0.1:8080/snakeviz/%2FUsers%2Fuclm%2FPycharmProjects%2FGSA_M%2Fnotebooks%2Fprofile.pstat
# ^C
#
# Bye!
